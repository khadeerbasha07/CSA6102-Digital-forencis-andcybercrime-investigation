# %% [markdown]
# <a href="https://colab.research.google.com/github/khadeerbasha07/CSA6102-Digital-forencis-andcybercrime-investigation/blob/main/debugging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
custody_log = []

def add_entry(evidence_id, handler, action):
    entry = {
        'evidence_id': evidence_id,
        'handler': handler,
        'action': action
    }
    custody_log.append(entry)

def print_log():
    for entry in custody_log:
        print(
            entry['evidence_id']
            + " - "
            + entry['handler']
            + " - "
            + entry['action']
        )

add_entry('EVD-101', 'A.Kumar', 'Collected')
add_entry('EVD-101', 'S.Rao', 'Analysed')

print_log()
# Out:
# EVD-101 - A.Kumar - Collected
# EVD-101 - S.Rao - Analysed
